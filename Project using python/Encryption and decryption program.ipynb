# %% [markdown]
# ## Coding Challenge 1, Basic Encryption
# - Follow the steps below to complete the task
# - It's highly recommended not to use AI generated code
# - make sure to add comments along the line
# - read about ceaser cypher encryption [here](https://en.wikipedia.org/wiki/Caesar_cipher)
#
# ### Happy coding

# %%
#Part One

#shifting a character

"You are going to shift a character by a certain number of positions"

"all ascii characters have a corresponding integer value for example the letter 'a' has an integer value of 97"
ord('a') #this code returns the integer value of a letter

""" write function that takes an integer value and a letter
converts the letter to it integer version and add the integer to that of
the converted letter's integer. Name your function as "Shift" """

#code here
def Shift(value, letter):
  converted_integer_value = ord(letter)

  return value + converted_integer_value

val = Shift(50, 'c')
# print(chr(val))
# Out:
# 

# %%
ord('a')
# Out:
# 97

# %%
#part two

"""Extend your function above to take a string for example "I will be great scientist" loop through the string and shift each character
return a list of all the integers you shifted
"""
#hint: in writing your loop use the len and range function since you don't know the len of the string

#code here
def Shift_upgrade(value, letter):
  # letter = list(input("Enter sentence to shift it's Equivalent integers:> "))
  # value = int(input("Enter the shifting magnitude(integers only):> "))
  # letter = list(letter)  # converting letter to list for easy iterations

  # Writing a for loop to iterate over the letter variable and convert each character of all the words it contain
  list_integers_to_be_shifted = []    # Creating an empty list collect integers to be converted
  shifted_integers = []   # Creating an empty list to collect the integers after shifting operation
  for i in letter:
    converted_integer_value = ord(i)
    # list_integers_to_be_shifted.append(converted_integer_value) # printing the integers to be listed to testing purpose. It is not good to print this out
    shifted_result = value + converted_integer_value
    shifted_integers.append(shifted_result)

  # print(list_integers_to_be_shifted)
  print("-------------------WOW IT WORKED--------------------")
  return shifted_integers


# test_variable = Shift_upgrade()
# print(f"Shifted integers: {test_variable}")

# %%
#part three

"""
You can also take an integer and convert it to a unicode/ascii character using the inbuilt chr function
"""
# print(chr(64)) # convert an integer to it corresponding unicode version and print to output

#Task

"""
improving on your code above, convert your shifted characters back to their ascii characters,
Make sure you make room for spaces and upper case letters
"""#hint: You might want to read about ascii characters and their corresponding int values

#code here
"""
Writing a function to retrive the ascii or unicode of the shifted integers

The function below takes the output of the shifted_upgrade function as input
"""
def encrypted_result(int_list):

  empty_list = []
  int_list = list(int_list)
  for i in int_list:
    ascii_value = chr(int(i))
    empty_list.append(ascii_value)

  return empty_list

# shifted_output = encrypted_result(test_variable)

# shifted_message = ''.join(shifted_output)

# print(f"List containing ascii letters of shifted integers: {shifted_output}")
# print(f"Encrypted message: {shifted_message}")

# for i in shifted_output:
  # print(i)

# %%
#Task:

# %%
#Part 4

#wrapping
""" in cases where the shift exceeded the integer values assigned to the unicode characters,
wrap around to let the shifting start from the beginning.
"""

#code here

# %%
#last part
""" Your function now takes a string of characters, an integer, and converts these strings to a certain number of characters
totally different from the input, basically your text has been encrypted
"""

#Task: Using the same logic as above, can you write another function that takes the decrypted text and the corresponding shift number
#Then decrypt the encrypted text back to it original text(you will have to perform a subtraction operation)
def Decrypting(value, encrypt_text):
  # value = int(input("Enter the same value(integer) used in encryption:> "))
  decrypt_list = []

  for i in encrypt_text:
    decrypt_list.append(ord(i) - value)
  # print(decrypt_list)
  return decrypt_list

# decrypted_text_integers = Decrypting(test_variable)

# Writing a for loop to convert all the integers to their corresponding ascii values
"""
decrypted_list = []
for i in decrypted_text_integers:
  decrypted_list.append(chr(i))

print(decrypted_list) # printing the decrypted text

decrypted_text = ''.join(decrypted_list)

print('----------------------Printing the decrypted text----------------------------')
print(decrypted_text)
"""
# Out:
# "\ndecrypted_list = []\nfor i in decrypted_text_integers:\n  decrypted_list.append(chr(i))\n\nprint(decrypted_list) # printing the decrypted text\n\ndecrypted_text = ''.join(decrypted_list)\n\nprint('----------------------Printing the decrypted text----------------------------')\nprint(decrypted_text)\n"

# %% [markdown]
# Name your encryption function as encrypt, and the decrytion functiond as decrypt

# %%
import time
# Text your functions (encrypt,decrypt using this code),

#Ask the user if they want to encrypt a text or decrypt a text
user_need=input("if you want to encrypt a text type ENCRYPT and if you want to decode a text type DECRYPT:> ")

user_need=user_need.lower()
#Encrypt or decrypt based on the user input

if user_need=="encrypt":
    global shift, test_variable, shifted_message
    print('\t\t\t\t\t\t****Encryption Process****')
    print('>>>>>Hello! Welcome to cipher encryption<<<<<<')
    text= input ("Please Enter The Text You Want encrypted: ")
    shift= int(input("Please Enter Shift Number: "))
    test_variable = Shift_upgrade(shift, text)

    encode=encrypted_result(test_variable)
    shifted_message = ''.join(encode)
    print('Encrypting...........0%')
    time.sleep(3)
    print('Encrypting..........25%')
    time.sleep(3)
    print('Encrypting..........50%')
    time.sleep(3)
    print('Encrypting..........75%')
    time.sleep(3)
    print('Encrypting.........100%')
    time.sleep(2)
    print('----------------------Printing the encrypted text----------------------------')

    print(f"{shifted_message}\n\nEncryption completed! ")
#decryption
elif user_need=='decrypt':
    print('\t\t\t\t\t\t****Decryption Process****')
    print('>>>>>Hello! Welcome to cipher decryption<<<<<<')
    # text= input ("Please Enter The Text You Want decrypted: ")
    # shift= int(input("Please Enter Shift Number: "))
    # test_variable = Shift_upgrade(shift, text)

    encode=encrypted_result(test_variable)

    decode=Decrypting(shift, encode)

    decrypted_list = []
    for i in decode:
      decrypted_list.append(chr(i))

    # print(f"List of decrypting characters: {decrypted_list}") # printing the decrypted text

    decrypted_text = ''.join(decrypted_list)
    print('Decrypting...........0%')
    time.sleep(3)
    print('Decrypting..........25%')
    time.sleep(3)
    print('Decrypting..........50%')
    time.sleep(3)
    print('Decrypting..........75%')
    time.sleep(3)
    print('Decrypting.........100%')
    time.sleep(2)

    print('----------------------Printing the decrypted text----------------------------')
    print(f"{shifted_message} ---> {decrypted_text}\n\nDecryption completed! ")
else:
    print('wrong input try again')
# Out:
# if you want to encrypt a text type ENCRYPT and if you want to decode a text type DECRYPT:> decrypt
# 						****Decryption Process****
# >>>>>Hello! Welcome to cipher decryption<<<<<<
# Decrypting...........0%
# Decrypting..........25%
# Decrypting..........50%
# Decrypting..........75%
# Decrypting.........100%
# ----------------------Printing the decrypted text----------------------------
# S*kx~*~y*zo|py|w*oxm|z~syx ---> I want to perform encryption
#
# Decryption completed!

# %%
#### IGNORE THE CELL BELOW:- I WAS EXPERIMENT WITH OTHER METHOD ####
"""
import time
# Text your functions (encrypt,decrypt using this code),

#Ask the user if they want to encrypt a text or decrypt a text
user_need=input("if you want to encrypt a text type ENCRYPT and if you want to decode a text type DECRYPT:> ")
text= input ("Please Enter The Text You Want encrypted: ")
shift= int(input("Please Enter Shift Number: "))

## Shifting the integer positions
test_variable = Shift_upgrade(shift, text)

## Encrypting the message using the new integers
encode=encrypted_result(test_variable)
shifted_message = ''.join(encode)

## Decrypting the encrypted text
decode=Decrypting(shift, encode)

decrypted_list = []
for i in decode:
  decrypted_list.append(chr(i))

# print(f"List of decrypting characters: {decrypted_list}") # printing the decrypted text

decrypted_text = ''.join(decrypted_list)


user_need=user_need.lower()
#Encrypt or decrypt based on the user input

if user_need=="encrypt":
    print('\t\t\t\t\t\t****Encryption Process****')
    print('>>>>>Hello! Welcome to cipher encryption<<<<<<')

    print('Encrypting...........0%')
    time.sleep(3)
    print('Encrypting..........25%')
    time.sleep(3)
    print('Encrypting..........50%')
    time.sleep(3)
    print('Encrypting..........75%')
    time.sleep(3)
    print('Encrypting.........100%')
    time.sleep(2)
    print('----------------------Printing the encrypted text----------------------------')

    print(f"{shifted_message}\n\nEncryption completed! ")
#decryption
elif user_need=='decrypt':
    print('\t\t\t\t\t\t****Decryption Process****')
    print('>>>>>Hello! Welcome to cipher decryption<<<<<<')
    # text= input ("Please Enter The Text You Want decrypted: ")
    # shift= int(input("Please Enter Shift Number: "))
    # test_variable = Shift_upgrade(shift, text)


    print('Decrypting...........0%')
    time.sleep(3)
    print('Decrypting..........25%')
    time.sleep(3)
    print('Decrypting..........50%')
    time.sleep(3)
    print('Decrypting..........75%')
    time.sleep(3)
    print('Decrypting.........100%')
    time.sleep(2)

    print('----------------------Printing the decrypted text----------------------------')
    print(f"{shifted_message}--->{decrypted_text}\n\nDecryption completed! ")
else:
    print('wrong input try again')
"""
# Out:
# if you want to encrypt a text type ENCRYPT and if you want to decode a text type DECRYPT:> decrypt
# Please Enter The Text You Want encrypted: I want to try the encryption method
# Please Enter Shift Number: 16
# -------------------WOW IT WORKED--------------------
# 						****Decryption Process****
# >>>>>Hello! Welcome to cipher decryption<<<<<<
# Decrypting...........0%
# Decrypting..........25%
# Decrypting..........50%
# Decrypting..........75%
# Decrypting.........100%
# ----------------------Printing the decrypted text----------------------------
# Y0q~000xu0u~sy~0}uxt--->I want to try the encryption method
#
# Decryption completed!

# %% [markdown]
# ## How it works:
#
# ### The Encryption process
#
# Hello, welcome to ceaser cipher encryption:
#
# Encrypting....
#
# input text: my name is sylvester
#
# shift number: 4
#
# encrypted text: qc reqi mw wcpziwxiv
#
# Encryption completed!
#
# ### Decryption process
#
# Hello, welcome to ceaser cipher encryption:
#
# Decrypting...
#
# my name is sylvester
#
# Decryption completed!
